# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

# %%
fname = r'states_202205241327.csv'

df = pd.read_csv(fname, sep=',')
df.head()
# Out:
#    state_id      domain                          entity_id          state  \
# 0         1      person                     person.georgii        unknown
# 1         2         sun                            sun.sun  above_horizon
# 2         3      script                  script.lumi_blink            off
# 3         4        zone                          zone.home         zoning
# 4         5  automation  automation.novaia_avtomatizatsiia             on
#
#                                           attributes  event_id  \
# 0  {"editable":false,"id":"georgii","source":"per...        32
# 1  {"next_dawn":"2022-05-25T02:45:38.202291+00:00...        48
# 2  {"last_triggered":"2022-05-20T15:00:09.414618+...        99
# 3  {"latitude":52.3731339,"longitude":4.8903147,"...       103
# 4  {"last_triggered":"2022-05-19T15:30:27.445792+...       130
#
#               last_changed             last_updated                  created  \
# 0  2022-05-24 09:19:07.241  2022-05-24 09:19:07.241  2022-05-24 09:19:07.241
# 1  2022-05-24 09:19:10.696  2022-05-24 09:19:10.696  2022-05-24 09:19:10.696
# 2  2022-05-24 09:19:27.417  2022-05-24 09:19:27.417  2022-05-24 09:19:27.417
# 3  2022-05-24 09:19:27.515  2022-05-24 09:19:27.515  2022-05-24 09:19:27.515
# 4  2022-05-24 09:19:28.716  2022-05-24 09:19:28.716  2022-05-24 09:19:28.716
#
#    old_state_id
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# выбор данных о работе датчика температуры (state:value)
ent_id = 'sensor.datchik_vlazhnosti_i_temperatury_temperature'
my_filter = (df['entity_id'] == ent_id) & (df['state'] != 'None') & (df['state'] != 'unknown')
my_columns = ['state', 'last_changed', 'last_updated', 'created']
df0 = df[my_filter][my_columns]
df0
# Out:
#      state             last_changed             last_updated  \
# 71   25.15  2022-05-24 09:44:35.698  2022-05-24 09:44:35.698
# 109  25.15  2022-05-24 10:02:38.624  2022-05-24 10:02:38.624
# 158   25.2  2022-05-24 10:10:40.561  2022-05-24 10:10:40.561
# 167  25.72  2022-05-24 10:11:59.363  2022-05-24 10:11:59.363
# 197  26.25  2022-05-24 10:15:43.131  2022-05-24 10:15:43.131
# 214  25.74  2022-05-24 10:18:29.273  2022-05-24 10:18:29.273
# 226  25.23  2022-05-24 10:22:15.896  2022-05-24 10:22:15.896
# 238  25.13  2022-05-24 10:25:48.498  2022-05-24 10:25:48.498
#
#                      created
# 71   2022-05-24 09:44:35.698
# 109  2022-05-24 10:02:38.624
# 158  2022-05-24 10:10:40.561
# 167  2022-05-24 10:11:59.363
# 197  2022-05-24 10:15:43.131
# 214  2022-05-24 10:18:29.273
# 226  2022-05-24 10:22:15.896
# 238  2022-05-24 10:25:48.498

# %%
X0 = list(df0['last_changed'])
Y0 = list(df0['state'])
Y0 = list(map(float, Y0))
X0, Y0
# Out:
# (['2022-05-24 09:44:35.698',
#   '2022-05-24 10:02:38.624',
#   '2022-05-24 10:10:40.561',
#   '2022-05-24 10:11:59.363',
#   '2022-05-24 10:15:43.131',
#   '2022-05-24 10:18:29.273',
#   '2022-05-24 10:22:15.896',
#   '2022-05-24 10:25:48.498'],
#  [25.15, 25.15, 25.2, 25.72, 26.25, 25.74, 25.23, 25.13])

# %%
# Формируем данные для построения графика

from datetime import datetime
def ConvDate(d, dd): # date -> millisec
    return (datetime.strptime(d, '%Y-%m-%d %H:%M:%S.%f').timestamp() * 1000 - dd) // 1e0

d0, d1 = X0[0], X0[-1]
delta = datetime.strptime(d0, '%Y-%m-%d %H:%M:%S.%f').timestamp() * 1000

                              
X, Y = [X0[0],], [Y0[0],]
for i in range(1, len(Y0)):
    X.append(X0[i])
    Y.append(Y0[i-1])
    X.append(X0[i])
    Y.append(Y0[i])

#X = list(map(lambda item: ConvDate(item, delta), X)) 

X, Y
# Out:
# (['2022-05-24 09:44:35.698',
#   '2022-05-24 10:02:38.624',
#   '2022-05-24 10:02:38.624',
#   '2022-05-24 10:10:40.561',
#   '2022-05-24 10:10:40.561',
#   '2022-05-24 10:11:59.363',
#   '2022-05-24 10:11:59.363',
#   '2022-05-24 10:15:43.131',
#   '2022-05-24 10:15:43.131',
#   '2022-05-24 10:18:29.273',
#   '2022-05-24 10:18:29.273',
#   '2022-05-24 10:22:15.896',
#   '2022-05-24 10:22:15.896',
#   '2022-05-24 10:25:48.498',
#   '2022-05-24 10:25:48.498'],
#  [25.15,
#   25.15,
#   25.15,
#   25.15,
#   25.2,
#   25.2,
#   25.72,
#   25.72,
#   26.25,
#   26.25,
#   25.74,
#   25.74,
#   25.23,
#   25.23,
#   25.13])

# %%
def cm_to_inch(value):
    return value/2.54

plt.figure(figsize=(cm_to_inch(45), cm_to_inch(15)))
plt.plot(X, Y)
plt.show()
